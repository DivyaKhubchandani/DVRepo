# %% [markdown]
# 1. Import the dataset in Jupyter Notebook using pandas library.

# %%
import pandas as pd

# %%
data=pd.read_csv(r"C:\Users\acer\Downloads\SmartWatch Data.csv")

# %%
data.head()
# Out:
#    X1  age  gender  height  weight      steps  hear_rate   calories  distance  \
# 0   1   20       1   168.0    65.4  10.771429  78.531302   0.344533  0.008327
# 1   2   20       1   168.0    65.4  11.475325  78.453390   3.287625  0.008896
# 2   3   20       1   168.0    65.4  12.179221  78.540825   9.484000  0.009466
# 3   4   20       1   168.0    65.4  12.883117  78.628260  10.154556  0.010035
# 4   5   20       1   168.0    65.4  13.587013  78.715695  10.825111  0.010605
#
#    entropy_heart  entropy_setps  resting_heart  corr_heart_steps  norm_heart  \
# 0       6.221612       6.116349           59.0          1.000000   19.531302
# 1       6.221612       6.116349           59.0          1.000000   19.453390
# 2       6.221612       6.116349           59.0          1.000000   19.540825
# 3       6.221612       6.116349           59.0          1.000000   19.628260
# 4       6.221612       6.116349           59.0          0.982816   19.715695
#
# ...

# %% [markdown]
# 2. Find out whether Supervised or Unsupervised Machine Learning should be used?

# %% [markdown]
# Supervised Machine learning should be used

# %% [markdown]
# 3. If Supervised, is this a problem statement of Regression or Classification?

# %% [markdown]
# Classification because the target is not in numerical form

# %% [markdown]
# 4. Check the quality of the data, it’s shape and data types

# %%
data.shape
# Out:
# (6264, 19)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6264 entries, 0 to 6263
# Data columns (total 19 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   X1                    6264 non-null   int64
#  1   age                   6264 non-null   int64
#  2   gender                6264 non-null   int64
#  3   height                6264 non-null   float64
#  4   weight                6264 non-null   float64
#  5   steps                 6264 non-null   float64
#  6   hear_rate             6264 non-null   float64
#  7   calories              6264 non-null   float64
#  8   distance              6264 non-null   float64
#  9   entropy_heart         6264 non-null   float64
#  10  entropy_setps         6264 non-null   float64
#  11  resting_heart         6264 non-null   float64
#  12  corr_heart_steps      6264 non-null   float64
#  13  norm_heart            6264 non-null   float64
# ...

# %%
df=data.copy()

# %% [markdown]
# 5. Check for null values, and apply appropriate techniques deal with it

# %%
data.isnull().any()
# Out:
# X1                      False
# age                     False
# gender                  False
# height                  False
# weight                  False
# steps                   False
# hear_rate               False
# calories                False
# distance                False
# entropy_heart           False
# entropy_setps           False
# resting_heart           False
# corr_heart_steps        False
# norm_heart              False
# intensity_karvonen      False
# sd_norm_heart           False
# steps_times_distance    False
# device                  False
# activity                False
# dtype: bool

# %%
df.drop("X1",axis=1,inplace=True)

# %% [markdown]
# 6. Find and remove outliers if any

# %%
data.describe()
# Out:
#                 X1          age       gender       height       weight  \
# count  6264.000000  6264.000000  6264.000000  6264.000000  6264.000000
# mean   1771.144317    29.158525     0.476533   169.709052    69.614464
# std    1097.988748     8.908978     0.499489    10.324698    13.451878
# min       1.000000    18.000000     0.000000   143.000000    43.000000
# 25%     789.750000    23.000000     0.000000   160.000000    60.000000
# 50%    1720.000000    28.000000     0.000000   168.000000    68.000000
# 75%    2759.250000    33.000000     1.000000   180.000000    77.300000
# max    3670.000000    56.000000     1.000000   191.000000   115.000000
#
#              steps    hear_rate     calories     distance  entropy_heart  \
# count  6264.000000  6264.000000  6264.000000  6264.000000    6264.000000
# mean    109.562268    86.142331    19.471823    13.832555       6.030314
# std     222.797908    28.648385    27.309765    45.941437       0.765574
# ...

# %% [markdown]
# In above vaues if any column has std value more than mean then it has ouliers

# %% [markdown]
# 7. Encode columns wherever required with appropriate Encoding Techniques

# %% [markdown]
# There are two columns which are not in numerical form Activity and device so we have to encode them

# %%
data['device'].unique()
# Out:
# array(['apple watch', 'fitbit'], dtype=object)

# %%
data['activity'].unique()
# Out:
# array(['Lying', 'Sitting', 'Self Pace walk', 'Running 3 METs',
#        'Running 5 METs', 'Running 7 METs'], dtype=object)

# %%
from sklearn import preprocessing

# %%
label_encoder = preprocessing.LabelEncoder()

# %%
df['device']= label_encoder.fit_transform(df['device'])

# %%
df['activity']= label_encoder.fit_transform(df['activity'])

# %%
df.head()
# Out:
#    age  gender  height  weight      steps  hear_rate   calories  distance  \
# 0   20       1   168.0    65.4  10.771429  78.531302   0.344533  0.008327
# 1   20       1   168.0    65.4  11.475325  78.453390   3.287625  0.008896
# 2   20       1   168.0    65.4  12.179221  78.540825   9.484000  0.009466
# 3   20       1   168.0    65.4  12.883117  78.628260  10.154556  0.010035
# 4   20       1   168.0    65.4  13.587013  78.715695  10.825111  0.010605
#
#    entropy_heart  entropy_setps  resting_heart  corr_heart_steps  norm_heart  \
# 0       6.221612       6.116349           59.0          1.000000   19.531302
# 1       6.221612       6.116349           59.0          1.000000   19.453390
# 2       6.221612       6.116349           59.0          1.000000   19.540825
# 3       6.221612       6.116349           59.0          1.000000   19.628260
# 4       6.221612       6.116349           59.0          0.982816   19.715695
#
# ...

# %%
df.corr()
# Out:
#                            age    gender    height    weight     steps  \
# age                   1.000000 -0.236032 -0.518798 -0.152317  0.006394
# gender               -0.236032  1.000000  0.735852  0.580446 -0.069719
# height               -0.518798  0.735852  1.000000  0.693504  0.025729
# weight               -0.152317  0.580446  0.693504  1.000000  0.045389
# steps                 0.006394 -0.069719  0.025729  0.045389  1.000000
# hear_rate            -0.007665 -0.093476 -0.123519 -0.064317  0.164084
# calories             -0.064661  0.071875  0.034447 -0.023612 -0.250973
# distance             -0.061169 -0.051779 -0.091422 -0.072294 -0.090433
# entropy_heart        -0.002541 -0.051111 -0.069491 -0.156601  0.021579
# entropy_setps        -0.001528  0.014608  0.049100 -0.052906  0.086400
# resting_heart        -0.022833 -0.082235 -0.028330 -0.014345  0.083964
# corr_heart_steps      0.068108 -0.039968 -0.031292 -0.064750 -0.229163
# ...

# %% [markdown]
# 9. Bifurcate the data as per predictors and target

# %%
x=df.drop("activity",axis=1)
y=df["activity"]

# %%
x.head()
# Out:
#    age  gender  height    weight     steps  hear_rate  calories  distance  \
# 0 -0.8     1.0     0.0 -0.150289  0.006748   0.062957 -0.184955 -0.011060
# 1 -0.8     1.0     0.0 -0.150289  0.013738   0.059076 -0.036044 -0.011023
# 2 -0.8     1.0     0.0 -0.150289  0.020729   0.063432  0.277472 -0.010987
# 3 -0.8     1.0     0.0 -0.150289  0.027720   0.067788  0.311400 -0.010951
# 4 -0.8     1.0     0.0 -0.150289  0.034711   0.072144  0.345328 -0.010914
#
#    entropy_heart  entropy_setps  resting_heart  corr_heart_steps  norm_heart  \
# 0       0.228023       -0.12068      -0.888673          0.227745    0.374532
# 1       0.228023       -0.12068      -0.888673          0.227745    0.371528
# 2       0.228023       -0.12068      -0.888673          0.227745    0.374900
# 3       0.228023       -0.12068      -0.888673          0.227745    0.378272
# 4       0.228023       -0.12068      -0.888673          0.216033    0.381644
#
# ...

# %%
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: activity, dtype: int32

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
df.hist(figsize=(10,10))
# Out:
# array([[<Axes: title={'center': 'age'}>,
#         <Axes: title={'center': 'gender'}>,
#         <Axes: title={'center': 'height'}>,
#         <Axes: title={'center': 'weight'}>],
#        [<Axes: title={'center': 'steps'}>,
#         <Axes: title={'center': 'hear_rate'}>,
#         <Axes: title={'center': 'calories'}>,
#         <Axes: title={'center': 'distance'}>],
#        [<Axes: title={'center': 'entropy_heart'}>,
#         <Axes: title={'center': 'entropy_setps'}>,
#         <Axes: title={'center': 'resting_heart'}>,
#         <Axes: title={'center': 'corr_heart_steps'}>],
#        [<Axes: title={'center': 'norm_heart'}>,
#         <Axes: title={'center': 'intensity_karvonen'}>,
#         <Axes: title={'center': 'sd_norm_heart'}>,
#         <Axes: title={'center': 'steps_times_distance'}>],
#        [<Axes: title={'center': 'device'}>,
#         <Axes: title={'center': 'activity'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %% [markdown]
# 10. Bifurcate the data for training and testing the model

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.8,random_state=42)

# %% [markdown]
# 11. Train the data with appropriate model.

# %%
from sklearn.ensemble import RandomForestClassifier
model=RandomForestClassifier(500,random_state=100)

# %%
model.fit(x_train,y_train)
# Out:
# RandomForestClassifier(n_estimators=500, random_state=100)

# %% [markdown]
# 12. Find out the accuracy which serves the best.

# %%
model.score(x_train,y_train)*100
# Out:
# 100.0

# %%
model.score(x_test,y_test)*100
# Out:
# 88.18834796488427

# %%
from sklearn.preprocessing import RobustScaler

# %%
Ro_scaler = RobustScaler()

# %%
df.head()
# Out:
#    age  gender  height    weight     steps  hear_rate  calories  distance  \
# 0 -0.8     1.0     0.0 -0.150289  0.006748   0.062957 -0.184955 -0.011060
# 1 -0.8     1.0     0.0 -0.150289  0.013738   0.059076 -0.036044 -0.011023
# 2 -0.8     1.0     0.0 -0.150289  0.020729   0.063432  0.277472 -0.010987
# 3 -0.8     1.0     0.0 -0.150289  0.027720   0.067788  0.311400 -0.010951
# 4 -0.8     1.0     0.0 -0.150289  0.034711   0.072144  0.345328 -0.010914
#
#    entropy_heart  entropy_setps  resting_heart  corr_heart_steps  norm_heart  \
# 0       0.228023       -0.12068      -0.888673          0.227745    0.374532
# 1       0.228023       -0.12068      -0.888673          0.227745    0.371528
# 2       0.228023       -0.12068      -0.888673          0.227745    0.374900
# 3       0.228023       -0.12068      -0.888673          0.227745    0.378272
# 4       0.228023       -0.12068      -0.888673          0.216033    0.381644
#
# ...

# %%
df[['age','gender','height','weight','steps','hear_rate','calories','distance','entropy_heart','entropy_setps','resting_heart','corr_heart_steps','norm_heart','intensity_karvonen','sd_norm_heart','steps_times_distance','device']]=Ro_scaler.fit_transform(df[['age','gender','height','weight','steps','hear_rate','calories','distance','entropy_heart','entropy_setps','resting_heart','corr_heart_steps','norm_heart','intensity_karvonen','sd_norm_heart','steps_times_distance','device']])

# %%
y_predicted=model.predict(x_test)

# %% [markdown]
# 13. Create a confusion matrix for the results achieved.

# %%
from sklearn.metrics import confusion_matrix

# %%
a=confusion_matrix(y_test,y_predicted)

# %%
import seaborn as sns

# %%
sns.heatmap(a,annot=True,cmap="Blues")
# Out:
# <Axes: >

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test,y_predicted))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.82      0.84       273
#            1       0.88      0.87      0.88       175
#            2       0.88      0.91      0.89       208
#            3       0.94      0.96      0.95       235
#            4       0.90      0.92      0.91       178
#            5       0.82      0.83      0.82       184
#
#     accuracy                           0.88      1253
#    macro avg       0.88      0.88      0.88      1253
# weighted avg       0.88      0.88      0.88      1253

# %%
import numpy as np

# %%
from sklearn.metrics import r2_score,mean_squared_error

# %%
r2_score(y_test,y_predicted)*100
# Out:
# 68.72211801004747

# %% [markdown]
# 14. Find out the Precision and Recall score.

# %%
print(classification_report(y_test,y_predicted))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.82      0.84       273
#            1       0.88      0.87      0.88       175
#            2       0.88      0.91      0.89       208
#            3       0.94      0.96      0.95       235
#            4       0.90      0.92      0.91       178
#            5       0.82      0.83      0.82       184
#
#     accuracy                           0.88      1253
#    macro avg       0.88      0.88      0.88      1253
# weighted avg       0.88      0.88      0.88      1253

# %% [markdown]
# 15. Based on the F1 score, is the model reliable?

# %% [markdown]
# F1=0.88, so model is somewhat reliable
